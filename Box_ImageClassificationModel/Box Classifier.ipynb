jpg
#   inflating: Boxes/1_Kontron/CamFront_20211104_144620.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211104_144620.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_124833.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_124833.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_18.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_18.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_30.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_30.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_24.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_24.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211112_084517.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211112_084517.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_25.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_25.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_31.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_31.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_19.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_19.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_120400.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_120400.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_120158.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_120158.jpg
#   inflating: Boxes/1_Kontron/IPEVO_CamFront_3.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._IPEVO_CamFront_3.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_123929.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_123929.jpg
#   inflating: Boxes/1_Kontron/IPEVO_CamFront_2.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._IPEVO_CamFront_2.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_105246.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_105246.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_110717.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_110717.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_105859.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_105859.jpg
#   inflating: Boxes/1_Kontron/IPEVO_CamFront_1.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._IPEVO_CamFront_1.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211104_144450.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211104_144450.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_125026.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_125026.jpg
#   inflating: Boxes/1_Kontron/IPEVO_CamFront_5.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._IPEVO_CamFront_5.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211029_114939.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211029_114939.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211112_090259.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211112_090259.jpg
#   inflating: Boxes/1_Kontron/IPEVO_CamFront_4.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._IPEVO_CamFront_4.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_113344.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_113344.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_111553.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_111553.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211104_150346.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211104_150346.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211029_110343.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211029_110343.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_115858.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_115858.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_124501.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_124501.jpg
#   inflating: Boxes/1_Kontron/IPEVO_CamFront_6.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._IPEVO_CamFront_6.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_110459.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_110459.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_115252.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_115252.jpg
#   inflating: Boxes/1_Kontron/IPEVO_CamFront_7.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._IPEVO_CamFront_7.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_111418.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_111418.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_114237.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_114237.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211104_150610.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211104_150610.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211104_145432.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211104_145432.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211027_131012.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211027_131012.jpg
#   inflating: Boxes/1_Kontron/IPEVO_CamFront_9.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._IPEVO_CamFront_9.jpg
#   inflating: Boxes/1_Kontron/IPEVO_CamFront_8.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._IPEVO_CamFront_8.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211104_125110.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211104_125110.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211112_083017.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211112_083017.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211112_090057.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211112_090057.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211112_083956.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211112_083956.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211104_124550.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211104_124550.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211112_085853.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211112_085853.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211027_130444.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211027_130444.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_114839.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_114839.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211104_144926.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211104_144926.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211027_123306.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211027_123306.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_111112.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_111112.jpg
#   inflating: Boxes/1_Kontron/IPEVO_CamFront_10.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._IPEVO_CamFront_10.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_14.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_14.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_3.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_3.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_28.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_28.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_105749.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_105749.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211112_083739.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211112_083739.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_29.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_29.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_2.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_2.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_15.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_15.jpg
#   inflating: Boxes/1_Kontron/IPEVO_CamFront_11.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._IPEVO_CamFront_11.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211104_145733.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211104_145733.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211027_132236.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211027_132236.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211027_122019.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211027_122019.jpg
#   inflating: Boxes/1_Kontron/IPEVO_CamFront_13.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._IPEVO_CamFront_13.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211112_085558.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211112_085558.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_0.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_0.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_17.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_17.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211029_111152.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211029_111152.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_16.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_16.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_1.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_1.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_125128.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_125128.jpg
#   inflating: Boxes/1_Kontron/IPEVO_CamFront_12.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._IPEVO_CamFront_12.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_113920.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_113920.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_105439.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_105439.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_5.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_5.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_12.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_12.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211029_105650.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211029_105650.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_13.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_13.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_4.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_4.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_11.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_11.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_6.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_6.jpg
#   inflating: Boxes/1_Kontron/CamFront_20211103_121822.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._CamFront_20211103_121822.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_7.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_7.jpg
#   inflating: Boxes/1_Kontron/WebcamFront_20220314_10.jpg
#   inflating: __MACOSX/Boxes/1_Kontron/._WebcamFront_20220314_10.jpg

# %% [markdown]
# # Data Loading and Pre-Processing

# %%
# Split data into train(70%), validation (20%) and test (10%) sets
splitfolders.ratio("Boxes", output="output", seed=1337, ratio=(0.7, 0.2, 0.1))

# Create imagefolders and transform data
train_folder = torchvision.datasets.ImageFolder('/content/output/train',
                                                transform =  torchvision.transforms.Compose([torchvision.transforms.ToTensor(),
                                                                                             torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
                                                                                             torchvision.transforms.RandomHorizontalFlip(),
                                                                                             torchvision.transforms.RandomVerticalFlip(),
                                                                                             torchvision.transforms.Resize((244,244))]))

val_folder = torchvision.datasets.ImageFolder('/content/output/val',
                                                transform =  torchvision.transforms.Compose([torchvision.transforms.ToTensor(),
                                                                                             torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
                                                                                             torchvision.transforms.RandomHorizontalFlip(),
                                                                                             torchvision.transforms.RandomVerticalFlip(),
                                                                                             torchvision.transforms.Resize((244,244))]))

test_folder = torchvision.datasets.ImageFolder('/content/output/test',
                                                transform =  torchvision.transforms.Compose([torchvision.transforms.ToTensor(),
                                                                                             torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
                                                                                             torchvision.transforms.RandomHorizontalFlip(),
                                                                                             torchvision.transforms.RandomVerticalFlip(),
                                                                                             torchvision.transforms.Resize((244,244))]))

# Dataloaders
train_dataloader = torch.utils.data.DataLoader(train_folder, batch_size=32, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_folder, batch_size=32)
test_dataloader = torch.utils.data.DataLoader(test_folder, batch_size=32)
# Out:
# Copying files: 198 files [00:00, 903.57 files/s]

# %% [markdown]
# # Training Loop

# %%
# Training Loop
def train_model(net, train_dataloader, val_dataloader):
  
  net = net.to('cuda')

  # Set optimizer and loss function (CrossEntropyLoss is necessary for binary classification)
  optimizer = torch.optim.Adam(net.parameters(), lr=3e-4)
  loss_fct = nn.CrossEntropyLoss()

  train_losses = []
  val_losses = []
  for t in range(10):

    # Train model
    net.train()

    epoch_train_loss = 0.
    for X_batch, y_batch in train_dataloader:
      X_batch = X_batch.to('cuda')
      y_batch = y_batch.to('cuda')

      y_pred = net(X_batch)

      loss = loss_fct(y_pred.squeeze(), y_batch.float())
      epoch_train_loss += loss

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

    train_losses.append(epoch_train_loss.cpu().data / len(train_dataloader))

    # Validate model
    net.eval()
    epoch_val_loss = 0.
    for X_batch, y_batch in val_dataloader:
      X_batch = X_batch.to('cuda')
      y_batch = y_batch.to('cuda')
      with torch.no_grad():
        y_pred_val = net(X_batch)
        loss = loss_fct(y_pred_val.squeeze(), y_batch.float())
        epoch_val_loss += loss
    val_losses.append(epoch_val_loss.cpu().data / len(val_dataloader))

  # ---------> UNCOMMENT TO SAVE TRAINED MODEL <---------
  #torch.save(net.state_dict(), f"/content/drive/MyDrive/DeepVis/PretrainedBinary/BoxClassifierPretrained.pth")

  return net

# %% [markdown]
# # Eval

# %%
# Evaluate a model on the test dataset

def evaluate_model(trained_model, test_dataloader):
  label_dict = {
    0:'AllenBradley',
    1:'Kontron' 
  }

  trained_model.eval()
  y_pred_list = []
  y_true_list = []
  for X_batch, y_batch in train_dataloader:
    X_batch = X_batch.to('cuda')
    y_pred = trained_model(X_batch)

    # Turn prediction into binary prediction (either 0 or 1)
    y_pred_list.extend((1 * (y_pred.squeeze() > 0.0)).tolist())
    y_true_list.extend(y_batch.tolist())

  pred = []
  true = []

  for i in range(len(y_pred_list)):
    pred.append(label_dict[y_pred_list[i]])
    true.append(label_dict[y_true_list[i]])

  print(classification_report(true, pred))

# %% [markdown]
# # Hand-crafted Model

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=5)
        self.pool = nn.MaxPool2d(kernel_size=2)
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5)

        self.fc1 = nn.Linear(in_features=107648, out_features=50)  
        # 24 output features, because we have 5 classes
        self.fc2 = nn.Linear(in_features=50, out_features=1)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        #print(x.shape)
        x = x.view(len(x), 107648)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
net = Net()
trained_model = train_model(net, train_dataloader, val_dataloader)
evaluate_model(trained_model, test_dataloader)
# Out:
#               precision    recall  f1-score   support
#
# AllenBradley       0.00      0.00      0.00        64
#      Kontron       0.54      1.00      0.70        74
#
#     accuracy                           0.54       138
#    macro avg       0.27      0.50      0.35       138
# weighted avg       0.29      0.54      0.37       138
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Transfer Learning

# %%
# Load pre-trained resnet18 model
net = models.resnet18(pretrained=True)

# Change output layer to a single class for binary classifcation
net.fc = nn.Linear(512, 1)

# Run training loop
trained_model = train_model(net, train_dataloader, val_dataloader)

# Evaluate trained model on test dataset
evaluate_model(trained_model, test_dataloader)
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#               precision    recall  f1-score   support
#
# AllenBradley       1.00      1.00      1.00        64
#      Kontron       1.00      1.00      1.00        74
#
#     accuracy                           1.00       138
#    macro avg       1.00      1.00      1.00       138
# weighted avg       1.00      1.00      1.00       138
