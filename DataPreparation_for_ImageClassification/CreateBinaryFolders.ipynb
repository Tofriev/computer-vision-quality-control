# %% [markdown]
# # Mount Drive and Import

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/DeepVis/
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-bad7a0746bfa> in <module>
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#       3 get_ipython().run_line_magic('cd', '/content/drive/MyDrive/DeepVis/')
#
# /usr/local/lib/python3.8/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      99 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     100   """Mount your Google Drive at the specified mountpoint path."""
# --> 101   return _mount(
#     102       mountpoint,
#     103       force_remount=force_remount,
#
# /usr/local/lib/python3.8/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     122       'TBE_EPHEM_CREDS_ADDR'] if ephemeral else _os.environ['TBE_CREDS_ADDR']
#     123   if ephemeral:
# --> 124     _message.blocking_request(
#     125         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     126
#
# /usr/local/lib/python3.8/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     169   request_id = send_request(
#     170       request_type, request, parent=parent, expect_reply=True)
# --> 171   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.8/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     100         reply.get('colab_msg_id') == message_id):
#     101       if 'error' in reply:
# --> 102         raise MessageError(reply['error'])
#     103       return reply.get('data', None)
#     104
#
# MessageError: Error: credential propagation was unsuccessful

# %%
import torchvision
import matplotlib.pyplot as plt
import numpy as np
import pickle
import copy
import os
import sys
import random
from sklearn.metrics import f1_score, roc_auc_score, classification_report
from sklearn.model_selection import train_test_split
import glob


import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# # Create Preprocessing.py file

# %%
# %%writefile Preprocessing.py
import os
import shutil
import random
import numpy as np
import torch
import pickle
import matplotlib.pyplot as plt


def set_seed(seed= 42):
    """
    src: https://wandb.ai/sauravmaheshkar/RSNA-MICCAI/reports/How-to-Set-Random-Seeds-in-PyTorch-and-Tensorflow--VmlldzoxMDA2MDQy
    """
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    # # When running on the CuDNN backend, two further options must be set
    # torch.backends.cudnn.deterministic = True
    # torch.backends.cudnn.benchmark = False
    # # Set a fixed value for the hash seed
    # os.environ["PYTHONHASHSEED"] = str(seed)
    print(f"Random seed set as {seed}")
    return

def save_model(epoch, model_state_dict, optimizer_state_dict, loss, path):
    torch.save(
        {
            'epoch': epoch+1,
            'model_state_dict': model_state_dict,
            'optimizer_state_dict': optimizer_state_dict,
            'loss': loss,
        }, path)

def save_model_config(cmp_dir, counts, files, train_losses, val_losses, config, report, auroc):
    out = {}
    for cmp in files:
        out[cmp] = (counts[cmp],files[cmp])
    with open(cmp_dir+"/dataset.pickle", 'wb') as handle:
        pickle.dump(out, handle, protocol=pickle.HIGHEST_PROTOCOL)
    plt.plot(train_losses)
    plt.plot(val_losses)
    plt.savefig(cmp_dir+"/plots.png")
    plt.show()
    plt.clf()
    plt.cla()
    plt.close()

    component = cmp_dir.split("/")[-1]
    with open(cmp_dir+"/"+component+"_model_results.txt", "w") as f:
        f.write(component + " report:\n")
        f.write(report)
        f.write("\n"*2)
        f.write("Auroc: "+str(auroc)+"\n")
        f.write("\n"*2)
        f.write("Training data distribution:\n")
        for key, value in counts.items():
            f.write(key+": "+str(value)+"\n")
        f.write("\n"*2)
        f.write("Configs:\n")
        for key, value in config.items():
            f.write(key+": "+ str(value)+"\n")
    
    

class DataCollector(object):
    """
    Class for the aggregation and creation of a model directory under "3_Hardware_Feature_Classification/Classifiers/"
    1. Instantiation asks for the component and the class distribution for the dataset
    2. After Instantiation the member of the false class can be configured through set_neg_categories()
       (By default it will consider every other component except CamBack, CamFront and CamTop)
    3. .create_dataset() will create the directory including the data folder
       - The 0 folder will contain (true_samples/class_dist) samples but no more than 8781 (total # of cropped imgs)
       - in favor for training the conv classifier, it incorporates the best possible variety into the false category
         by balancing the other components.
    """
    #Pfad für cropped images hinterlegen
    component_dir = "Data/Features_Cropped/"
    # In diesem Pfad werden Ornder mit neuen Datensätzen gespeichert
    classifier_dir = "Data/binary_classification/"
    #excl_categories = ["0_CamFront_cropped"] #, "CamFront", "CamTop"]

    def __init__(self, component, class_dist=None, subfolder=""):
        self.component = component
        self.class_dist = class_dist
        self.neg_categories = self.read_categories()
        self.dir = None
        self.total_pos_cat = None
        self.total_neg_cat = None
        self.dist_dict = None
        self.dist_dict_files = None
        self.subfolder = subfolder
        if subfolder != "":
            if not os.path.exists(DataCollector.classifier_dir+self.subfolder):
                os.mkdir(DataCollector.classifier_dir+self.subfolder)

    # Remove unwanted folders (images of cropped boxes)
    def read_categories(self):
        neg_categories = os.listdir(DataCollector.component_dir)
        neg_categories.remove(self.component)
        #for i in DataCollector.excl_categories:
        #    neg_categories.remove(i)
        return neg_categories

    def set_neg_categories(self, new_list):
        self.neg_categories = new_list

    def create_dataset(self):
        # Create new dir in Classifiers
        new_dir = self.unique_dir()
        self.dir = DataCollector.classifier_dir+self.subfolder+new_dir
        os.mkdir(self.dir)
        #os.mkdir(self.dir + "/data")

        # Create data/1 folder for true samples
        shutil.copytree(DataCollector.component_dir + self.component, self.dir + "/1")
        # os.rename(self.dir + "/data/" + self.component, self.dir + "/data/1")
        self.total_pos_cat = len(os.listdir(self.dir + "/1"))

        # Aggregate samples from neg_categories
        os.mkdir(self.dir + "/0")
        self.dist_dict = self.calc_dist()
        self.dist_dict_files = {}
        for cmp, count in self.dist_dict.items():
            img_list = os.listdir(DataCollector.component_dir + cmp)
            random.seed(42)
            random.shuffle(img_list)
            self.dist_dict_files[cmp] = img_list
            for img in img_list[:count]:
                source = DataCollector.component_dir + "/" + cmp + "/" + img
                destination = self.dir + "/0/" + img
                if os.path.isfile(source):
                    shutil.copy(source, destination)
        return self.dir

    def calc_dist(self):
        no_selection = {}
        for cmp in self.neg_categories:
            no_selection[cmp] = len(os.listdir(DataCollector.component_dir + cmp))
        maximum = sum([no_selection[cmp] for cmp in no_selection])
        if self.class_dist is None:
            self.total_neg_cat = maximum
            return no_selection

        selected = 0
        selection = {}
        self.total_neg_cat = round(self.total_pos_cat/self.class_dist-self.total_pos_cat)
        optimal = round(self.total_neg_cat / len(self.neg_categories))
        # in case of rounding up, optimal gets too big
        optimal = optimal -1

        for cmp in self.neg_categories:
            cmp_count = no_selection[cmp]
            if cmp_count <= optimal:
                selection[cmp] = {"count":cmp_count, "complete":True}
                selected += cmp_count
            else:
                selection[cmp] = {"count":optimal, "complete":False}
                selected += optimal

        while selected < min(self.total_neg_cat, maximum):
            for cmp in selection:
                if selection[cmp]["complete"]:
                    continue
                selection[cmp]["count"] += 1
                selected += 1
                if selection[cmp]["count"] == no_selection[cmp]:
                    selection[cmp]["complete"] = True
                if selected == min(self.total_neg_cat, maximum):
                    break

        selection = {cmp:value["count"] for (cmp,value) in selection.items()}
        return selection

    def unique_dir(self):
        dirs = os.listdir(DataCollector.classifier_dir+self.subfolder)
        i = 0
        dir_name = self.component + "_" + str(i)
        while dir_name in dirs:
            i+=1
            dir_name = self.component + "_" + str(i)
        return dir_name

    def get_class_dist(self):
        with_pos = self.dist_dict
        with_pos[self.component] = self.total_pos_cat
        return with_pos
    def get_file_lists(self):
        with_pos = self.dist_dict_files
        with_pos[self.component] = os.listdir(DataCollector.component_dir + self.component)
        return with_pos
# Out:
# Writing Preprocessing.py

# %%
# %cd ../
# Out:
# /content/drive/.shortcut-targets-by-id/1ynjnztWTKNm61JB9EqcrKvlbbIcz0MRu/DeepVis

# %%
# !ls
# Out:
# 'Binary Classification (hand-crafted).ipynb'   Kontron
#  CreateBinaryFolders.ipynb		       KristofPreprocessing.py
#  Data					       Preprocessing.py
# 'Data2 (can be ignored)'		      'Project Notebooks'
# 'DeepVis Datapreprocessing.ipynb'	       __pycache__
# 'Exercise Notebooks'			       ResNet_v2.ipynb
#  ImageCropping.ipynb			       ResNet_v3.ipynb

# %%
# Own modules
from Preprocessing import DataCollector, save_model, save_model_config

# %% [markdown]
# # Create Dataset for Binary Classification

# %%
#create list with the names of all hardware feature folders

#%cd /content/drive/MyDrive/DeepVis/Data/Features_Cropped/
#features = glob.glob('*')
#features
# %cd ../../
# Out:
# /content/drive/.shortcut-targets-by-id/1ynjnztWTKNm61JB9EqcrKvlbbIcz0MRu/DeepVis

# %%
# loop through all hardware features and create binary classification dataset using Preprocessing.py

for feature in features:

  config = {
      # Name von Folder des cropped img bei component angeben
      "component":f"{feature}",
  # Define training data class (im)-balance:
      "class_distribution": 0.5, # None: --> Train with all components (high imbalance)
      "epochs": 100,
      "batch_size": 32,
      "lr": 3e-4,
      "prediction_threshold": 0.5}

    # Aggregation/Selection of training data & Creation of directory
  # 1. Initialization
  dataspace = DataCollector(config["component"], config["class_distribution"])

  # 2. Excluding components from the neg category
  include_only = ["component_name1", "component_name2"]
  # dataspace.set_neg_categories(include_only)

  # 3. Creation
  fpath = dataspace.create_dataset()

  # See Class Distribution
  print(dataspace.get_class_dist())
  print(fpath)
# Out:
# {'11_LOGO_Kontron_icon': 5, '12_Power_5V': 5, '13_Powerstecker_off': 5, '14_Powerstecker_on': 5, '15_Reset_button': 5, '16_Schraube': 5, '17_Schraube_abstand': 5, '18_Schraube_gespiegelt': 5, '19_Schraube_halb': 5, '20_Schraube_rund': 5, '21_USB_2': 5, '22_USB_3': 5, '23_VGA': 5, '00_COM_male': 5, '01_Display_Port': 4, '02_Ethernet': 4, '03_LED_HDD': 4, '04_LED_PWR': 4, '05_LED_SSD': 4, '06_Line_out': 4, '07_Loch': 4, '08_LOGO_AllenBradley_font': 4, '09_LOGO_AllenBradley_icon': 4, '10_LOGO_Kontron_font': 106}
# Data/binary_classification/10_LOGO_Kontron_font_0
# {'10_LOGO_Kontron_font': 3, '12_Power_5V': 3, '13_Powerstecker_off': 3, '14_Powerstecker_on': 3, '15_Reset_button': 3, '16_Schraube': 2, '17_Schraube_abstand': 2, '18_Schraube_gespiegelt': 2, '19_Schraube_halb': 2, '20_Schraube_rund': 2, '21_USB_2': 2, '22_USB_3': 2, '23_VGA': 2, '00_COM_male': 2, '01_Display_Port': 2, '02_Ethernet': 2, '03_LED_HDD': 2, '04_LED_PWR': 2, '05_LED_SSD': 2, '06_Line_out': 2, '07_Loch': 2, '08_LOGO_AllenBradley_font': 2, '09_LOGO_AllenBradley_icon': 2, '11_LOGO_Kontron_icon': 51}
# Data/binary_classification/11_LOGO_Kontron_icon_0
# {'10_LOGO_Kontron_font': 5, '11_LOGO_Kontron_icon': 4, '13_Powerstecker_off': 4, '14_Powerstecker_on': 4, '15_Reset_button': 4, '16_Schraube': 4, '17_Schraube_abstand': 4, '18_Schraube_gespiegelt': 4, '19_Schraube_halb': 4, '20_Schraube_rund': 4, '21_USB_2': 4, '22_USB_3': 4, '23_VGA': 4, '00_COM_male': 4, '01_Display_Port': 4, '02_Ethernet': 4, '03_LED_HDD': 4, '04_LED_PWR': 4, '05_LED_SSD': 4, '06_Line_out': 4, '07_Loch': 4, '08_LOGO_AllenBradley_font': 4, '09_LOGO_AllenBradley_icon': 4, '12_Power_5V': 93}
# Data/binary_classification/12_Power_5V_0
# {'10_LOGO_Kontron_font': 3, '11_LOGO_Kontron_icon': 3, '12_Power_5V': 3, '14_Powerstecker_on': 3, '15_Reset_button': 3, '16_Schraube': 3, '17_Schraube_abstand': 3, '18_Schraube_gespiegelt': 3, '19_Schraube_halb': 3, '20_Schraube_rund': 3, '21_USB_2': 3, '22_USB_3': 2, '23_VGA': 2, '00_COM_male': 2, '01_Display_Port': 2, '02_Ethernet': 2, '03_LED_HDD': 2, '04_LED_PWR': 2, '05_LED_SSD': 2, '06_Line_out': 2, '07_Loch': 2, '08_LOGO_AllenBradley_font': 2, '09_LOGO_AllenBradley_icon': 2, '13_Powerstecker_off': 57}
# Data/binary_classification/13_Powerstecker_off_0
# {'10_LOGO_Kontron_font': 3, '11_LOGO_Kontron_icon': 3, '12_Power_5V': 3, '13_Powerstecker_off': 2, '15_Reset_button': 2, '16_Schraube': 2, '17_Schraube_abstand': 2, '18_Schraube_gespiegelt': 2, '19_Schraube_halb': 2, '20_Schraube_rund': 2, '21_USB_2': 2, '22_USB_3': 2, '23_VGA': 2, '00_COM_male': 2, '01_Display_Port': 2, '02_Ethernet': 2, '03_LED_HDD': 2, '04_LED_PWR': 2, '05_LED_SSD': 2, '06_Line_out': 2, '07_Loch': 2, '08_LOGO_AllenBradley_font': 2, '09_LOGO_AllenBradley_icon': 2, '14_Powerstecker_on': 49}
# Data/binary_classification/14_Powerstecker_on_0
# {'10_LOGO_Kontron_font': 9, '11_LOGO_Kontron_icon': 9, '12_Power_5V': 9, '13_Powerstecker_off': 9, '14_Powerstecker_on': 9, '16_Schraube': 9, '17_Schraube_abstand': 9, '18_Schraube_gespiegelt': 9, '19_Schraube_halb': 9, '20_Schraube_rund': 9, '21_USB_2': 9, '22_USB_3': 9, '23_VGA': 9, '00_COM_male': 9, '01_Display_Port': 9, '02_Ethernet': 8, '03_LED_HDD': 8, '04_LED_PWR': 8, '05_LED_SSD': 8, '06_Line_out': 8, '07_Loch': 8, '08_LOGO_AllenBradley_font': 8, '09_LOGO_AllenBradley_icon': 8, '15_Reset_button': 199}
# Data/binary_classification/15_Reset_button_0
# {'10_LOGO_Kontron_font': 27, '11_LOGO_Kontron_icon': 27, '12_Power_5V': 27, '13_Powerstecker_off': 27, '14_Powerstecker_on': 27, '15_Reset_button': 27, '17_Schraube_abstand': 27, '18_Schraube_gespiegelt': 26, '19_Schraube_halb': 26, '20_Schraube_rund': 26, '21_USB_2': 26, '22_USB_3': 26, '23_VGA': 26, '00_COM_male': 26, '01_Display_Port': 26, '02_Ethernet': 26, '03_LED_HDD': 26, '04_LED_PWR': 26, '05_LED_SSD': 26, '06_Line_out': 26, '07_Loch': 26, '08_LOGO_AllenBradley_font': 26, '09_LOGO_AllenBradley_icon': 26, '16_Schraube': 605}
# Data/binary_classification/16_Schraube_0
# {'10_LOGO_Kontron_font': 19, '11_LOGO_Kontron_icon': 19, '12_Power_5V': 19, '13_Powerstecker_off': 19, '14_Powerstecker_on': 19, '15_Reset_button': 19, '16_Schraube': 19, '18_Schraube_gespiegelt': 19, '19_Schraube_halb': 19, '20_Schraube_rund': 19, '21_USB_2': 19, '22_USB_3': 19, '23_VGA': 19, '00_COM_male': 19, '01_Display_Port': 19, '02_Ethernet': 19, '03_LED_HDD': 19, '04_LED_PWR': 19, '05_LED_SSD': 19, '06_Line_out': 19, '07_Loch': 19, '08_LOGO_AllenBradley_font': 18, '09_LOGO_AllenBradley_icon': 18, '17_Schraube_abstand': 435}
# Data/binary_classification/17_Schraube_abstand_0
# {'10_LOGO_Kontron_font': 20, '11_LOGO_Kontron_icon': 20, '12_Power_5V': 20, '13_Powerstecker_off': 20, '14_Powerstecker_on': 20, '15_Reset_button': 20, '16_Schraube': 20, '17_Schraube_abstand': 20, '19_Schraube_halb': 20, '20_Schraube_rund': 20, '21_USB_2': 20, '22_USB_3': 20, '23_VGA': 20, '00_COM_male': 20, '01_Display_Port': 20, '02_Ethernet': 19, '03_LED_HDD': 19, '04_LED_PWR': 19, '05_LED_SSD': 19, '06_Line_out': 19, '07_Loch': 19, '08_LOGO_AllenBradley_font': 19, '09_LOGO_AllenBradley_icon': 19, '18_Schraube_gespiegelt': 452}
# Data/binary_classification/18_Schraube_gespiegelt_0
# {'10_LOGO_Kontron_font': 5, '11_LOGO_Kontron_icon': 5, '12_Power_5V': 5, '13_Powerstecker_off': 5, '14_Powerstecker_on': 5, '15_Reset_button': 5, '16_Schraube': 5, '17_Schraube_abstand': 5, '18_Schraube_gespiegelt': 5, '20_Schraube_rund': 5, '21_USB_2': 5, '22_USB_3': 5, '23_VGA': 5, '00_COM_male': 5, '01_Display_Port': 5, '02_Ethernet': 5, '03_LED_HDD': 5, '04_LED_PWR': 5, '05_LED_SSD': 5, '06_Line_out': 5, '07_Loch': 5, '08_LOGO_AllenBradley_font': 5, '09_LOGO_AllenBradley_icon': 5, '19_Schraube_halb': 115}
# Data/binary_classification/19_Schraube_halb_0
# {'10_LOGO_Kontron_font': 24, '11_LOGO_Kontron_icon': 24, '12_Power_5V': 24, '13_Powerstecker_off': 24, '14_Powerstecker_on': 24, '15_Reset_button': 23, '16_Schraube': 23, '17_Schraube_abstand': 23, '18_Schraube_gespiegelt': 23, '19_Schraube_halb': 23, '21_USB_2': 23, '22_USB_3': 23, '23_VGA': 23, '00_COM_male': 23, '01_Display_Port': 23, '02_Ethernet': 23, '03_LED_HDD': 23, '04_LED_PWR': 23, '05_LED_SSD': 23, '06_Line_out': 23, '07_Loch': 23, '08_LOGO_AllenBradley_font': 23, '09_LOGO_AllenBradley_icon': 23, '20_Schraube_rund': 534}
# Data/binary_classification/20_Schraube_rund_0
# {'10_LOGO_Kontron_font': 22, '11_LOGO_Kontron_icon': 22, '12_Power_5V': 22, '13_Powerstecker_off': 22, '14_Powerstecker_on': 22, '15_Reset_button': 22, '16_Schraube': 22, '17_Schraube_abstand': 22, '18_Schraube_gespiegelt': 21, '19_Schraube_halb': 21, '20_Schraube_rund': 21, '22_USB_3': 21, '23_VGA': 21, '00_COM_male': 21, '01_Display_Port': 21, '02_Ethernet': 21, '03_LED_HDD': 21, '04_LED_PWR': 21, '05_LED_SSD': 21, '06_Line_out': 21, '07_Loch': 21, '08_LOGO_AllenBradley_font': 21, '09_LOGO_AllenBradley_icon': 21, '21_USB_2': 491}
# Data/binary_classification/21_USB_2_0
# {'10_LOGO_Kontron_font': 11, '11_LOGO_Kontron_icon': 11, '12_Power_5V': 11, '13_Powerstecker_off': 11, '14_Powerstecker_on': 11, '15_Reset_button': 11, '16_Schraube': 11, '17_Schraube_abstand': 11, '18_Schraube_gespiegelt': 11, '19_Schraube_halb': 11, '20_Schraube_rund': 11, '21_USB_2': 11, '23_VGA': 11, '00_COM_male': 11, '01_Display_Port': 11, '02_Ethernet': 11, '03_LED_HDD': 11, '04_LED_PWR': 11, '05_LED_SSD': 11, '06_Line_out': 11, '07_Loch': 10, '08_LOGO_AllenBradley_font': 10, '09_LOGO_AllenBradley_icon': 10, '22_USB_3': 250}
# Data/binary_classification/22_USB_3_0
# {'10_LOGO_Kontron_font': 3, '11_LOGO_Kontron_icon': 3, '12_Power_5V': 3, '13_Powerstecker_off': 3, '14_Powerstecker_on': 3, '15_Reset_button': 3, '16_Schraube': 3, '17_Schraube_abstand': 3, '18_Schraube_gespiegelt': 3, '19_Schraube_halb': 2, '20_Schraube_rund': 2, '21_USB_2': 2, '22_USB_3': 2, '00_COM_male': 2, '01_Display_Port': 2, '02_Ethernet': 2, '03_LED_HDD': 2, '04_LED_PWR': 2, '05_LED_SSD': 2, '06_Line_out': 2, '07_Loch': 2, '08_LOGO_AllenBradley_font': 2, '09_LOGO_AllenBradley_icon': 2, '23_VGA': 55}
# Data/binary_classification/23_VGA_0
# {'10_LOGO_Kontron_font': 5, '11_LOGO_Kontron_icon': 5, '12_Power_5V': 5, '13_Powerstecker_off': 5, '14_Powerstecker_on': 5, '15_Reset_button': 5, '16_Schraube': 5, '17_Schraube_abstand': 5, '18_Schraube_gespiegelt': 5, '19_Schraube_halb': 5, '20_Schraube_rund': 5, '21_USB_2': 5, '22_USB_3': 5, '23_VGA': 5, '01_Display_Port': 4, '02_Ethernet': 4, '03_LED_HDD': 4, '04_LED_PWR': 4, '05_LED_SSD': 4, '06_Line_out': 4, '07_Loch': 4, '08_LOGO_AllenBradley_font': 4, '09_LOGO_AllenBradley_icon': 4, '00_COM_male': 106}
# Data/binary_classification/00_COM_male_0
# {'10_LOGO_Kontron_font': 9, '11_LOGO_Kontron_icon': 9, '12_Power_5V': 9, '13_Powerstecker_off': 9, '14_Powerstecker_on': 9, '15_Reset_button': 9, '16_Schraube': 9, '17_Schraube_abstand': 9, '18_Schraube_gespiegelt': 9, '19_Schraube_halb': 9, '20_Schraube_rund': 9, '21_USB_2': 9, '22_USB_3': 9, '23_VGA': 9, '00_COM_male': 9, '02_Ethernet': 8, '03_LED_HDD': 8, '04_LED_PWR': 8, '05_LED_SSD': 8, '06_Line_out': 8, '07_Loch': 8, '08_LOGO_AllenBradley_font': 8, '09_LOGO_AllenBradley_icon': 8, '01_Display_Port': 199}
# Data/binary_classification/01_Display_Port_0
# {'10_LOGO_Kontron_font': 14, '11_LOGO_Kontron_icon': 14, '12_Power_5V': 14, '13_Powerstecker_off': 14, '14_Powerstecker_on': 14, '15_Reset_button': 14, '16_Schraube': 13, '17_Schraube_abstand': 13, '18_Schraube_gespiegelt': 13, '19_Schraube_halb': 13, '20_Schraube_rund': 13, '21_USB_2': 13, '22_USB_3': 13, '23_VGA': 13, '00_COM_male': 13, '01_Display_Port': 13, '03_LED_HDD': 13, '04_LED_PWR': 13, '05_LED_SSD': 13, '06_Line_out': 13, '07_Loch': 13, '08_LOGO_AllenBradley_font': 13, '09_LOGO_AllenBradley_icon': 13, '02_Ethernet': 305}
# Data/binary_classification/02_Ethernet_0
# {'10_LOGO_Kontron_font': 3, '11_LOGO_Kontron_icon': 3, '12_Power_5V': 3, '13_Powerstecker_off': 3, '14_Powerstecker_on': 3, '15_Reset_button': 2, '16_Schraube': 2, '17_Schraube_abstand': 2, '18_Schraube_gespiegelt': 2, '19_Schraube_halb': 2, '20_Schraube_rund': 2, '21_USB_2': 2, '22_USB_3': 2, '23_VGA': 2, '00_COM_male': 2, '01_Display_Port': 2, '02_Ethernet': 2, '04_LED_PWR': 2, '05_LED_SSD': 2, '06_Line_out': 2, '07_Loch': 2, '08_LOGO_AllenBradley_font': 2, '09_LOGO_AllenBradley_icon': 2, '03_LED_HDD': 51}
# Data/binary_classification/03_LED_HDD_0
# {'10_LOGO_Kontron_font': 9, '11_LOGO_Kontron_icon': 9, '12_Power_5V': 9, '13_Powerstecker_off': 9, '14_Powerstecker_on': 9, '15_Reset_button': 9, '16_Schraube': 9, '17_Schraube_abstand': 9, '18_Schraube_gespiegelt': 9, '19_Schraube_halb': 9, '20_Schraube_rund': 9, '21_USB_2': 9, '22_USB_3': 9, '23_VGA': 9, '00_COM_male': 9, '01_Display_Port': 8, '02_Ethernet': 8, '03_LED_HDD': 8, '05_LED_SSD': 8, '06_Line_out': 8, '07_Loch': 8, '08_LOGO_AllenBradley_font': 8, '09_LOGO_AllenBradley_icon': 8, '04_LED_PWR': 199}
# Data/binary_classification/04_LED_PWR_0
# {'10_LOGO_Kontron_font': 3, '11_LOGO_Kontron_icon': 3, '12_Power_5V': 3, '13_Powerstecker_off': 3, '14_Powerstecker_on': 3, '15_Reset_button': 3, '16_Schraube': 3, '17_Schraube_abstand': 3, '18_Schraube_gespiegelt': 3, '19_Schraube_halb': 2, '20_Schraube_rund': 2, '21_USB_2': 2, '22_USB_3': 2, '23_VGA': 2, '00_COM_male': 2, '01_Display_Port': 2, '02_Ethernet': 2, '03_LED_HDD': 2, '04_LED_PWR': 2, '06_Line_out': 2, '07_Loch': 2, '08_LOGO_AllenBradley_font': 2, '09_LOGO_AllenBradley_icon': 2, '05_LED_SSD': 55}
# Data/binary_classification/05_LED_SSD_0
# {'10_LOGO_Kontron_font': 5, '11_LOGO_Kontron_icon': 4, '12_Power_5V': 4, '13_Powerstecker_off': 4, '14_Powerstecker_on': 4, '15_Reset_button': 4, '16_Schraube': 4, '17_Schraube_abstand': 4, '18_Schraube_gespiegelt': 4, '19_Schraube_halb': 4, '20_Schraube_rund': 4, '21_USB_2': 4, '22_USB_3': 4, '23_VGA': 4, '00_COM_male': 4, '01_Display_Port': 4, '02_Ethernet': 4, '03_LED_HDD': 4, '04_LED_PWR': 4, '05_LED_SSD': 4, '07_Loch': 4, '08_LOGO_AllenBradley_font': 4, '09_LOGO_AllenBradley_icon': 4, '06_Line_out': 93}
# Data/binary_classification/06_Line_out_0
# {'10_LOGO_Kontron_font': 4, '11_LOGO_Kontron_icon': 4, '12_Power_5V': 4, '13_Powerstecker_off': 4, '14_Powerstecker_on': 4, '15_Reset_button': 4, '16_Schraube': 4, '17_Schraube_abstand': 3, '18_Schraube_gespiegelt': 3, '19_Schraube_halb': 3, '20_Schraube_rund': 3, '21_USB_2': 3, '22_USB_3': 3, '23_VGA': 3, '00_COM_male': 3, '01_Display_Port': 3, '02_Ethernet': 3, '03_LED_HDD': 3, '04_LED_PWR': 3, '05_LED_SSD': 3, '06_Line_out': 3, '08_LOGO_AllenBradley_font': 3, '09_LOGO_AllenBradley_icon': 3, '07_Loch': 76}
# Data/binary_classification/07_Loch_0
# {'10_LOGO_Kontron_font': 5, '11_LOGO_Kontron_icon': 4, '12_Power_5V': 4, '13_Powerstecker_off': 4, '14_Powerstecker_on': 4, '15_Reset_button': 4, '16_Schraube': 4, '17_Schraube_abstand': 4, '18_Schraube_gespiegelt': 4, '19_Schraube_halb': 4, '20_Schraube_rund': 4, '21_USB_2': 4, '22_USB_3': 4, '23_VGA': 4, '00_COM_male': 4, '01_Display_Port': 4, '02_Ethernet': 4, '03_LED_HDD': 4, '04_LED_PWR': 4, '05_LED_SSD': 4, '06_Line_out': 4, '07_Loch': 4, '09_LOGO_AllenBradley_icon': 4, '08_LOGO_AllenBradley_font': 93}
# Data/binary_classification/08_LOGO_AllenBradley_font_0
# {'10_LOGO_Kontron_font': 5, '11_LOGO_Kontron_icon': 4, '12_Power_5V': 4, '13_Powerstecker_off': 4, '14_Powerstecker_on': 4, '15_Reset_button': 4, '16_Schraube': 4, '17_Schraube_abstand': 4, '18_Schraube_gespiegelt': 4, '19_Schraube_halb': 4, '20_Schraube_rund': 4, '21_USB_2': 4, '22_USB_3': 4, '23_VGA': 4, '00_COM_male': 4, '01_Display_Port': 4, '02_Ethernet': 4, '03_LED_HDD': 4, '04_LED_PWR': 4, '05_LED_SSD': 4, '06_Line_out': 4, '07_Loch': 4, '08_LOGO_AllenBradley_font': 4, '09_LOGO_AllenBradley_icon': 93}
# Data/binary_classification/09_LOGO_AllenBradley_icon_0
